# %% [markdown]
# # Multiple classification using CNN

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# Out:
# WARNING:tensorflow:From C:\Users\pater\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Load the Image Training and Validation Datasets

# %%
train_dataset_path = "C:/Users/pater/OneDrive/Documents/Code Practice/Deep Learning with Python/imgClassCNN/seg_train/seg_train"
validation_dataset_path = "C:/Users/pater/OneDrive/Documents/Code Practice/Deep Learning with Python/imgClassCNN/seg_test/seg_test"

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 6277 images belonging to 6 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : buildings
# 1 : forest
# 2 : glacier
# 3 : mountain
# 4 : sea
# 5 : street

# %% [markdown]
# Plotting Sample Training Images

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# Training a CNN Model

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=6, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()
print(cnn_model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\pater\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\pater\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 128)     9728
#
#  activation (Activation)     (None, 146, 146, 128)     0
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 128)       0
#  D)
#
#  batch_normalization (Batch  (None, 73, 73, 128)       512
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 71, 71, 64)        73792
#
#  activation_1 (Activation)   (None, 71, 71, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 35, 35, 64)        256
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 33, 33, 32)        18464
#
#  activation_2 (Activation)   (None, 33, 33, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 2201830 (8.40 MB)
# Trainable params: 2201382 (8.40 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
optimizer = Adam(learning_rate=0.001)
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# Training the Model

# %%
history = cnn_model.fit(train_generator, epochs=30, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\pater\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\pater\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 197/197 - 660s - loss: 2.5937 - accuracy: 0.4690 - val_loss: 2.9889 - val_accuracy: 0.2273 - lr: 0.0010 - 660s/epoch - 3s/step
# Epoch 2/30
# 197/197 - 512s - loss: 1.6441 - accuracy: 0.5275 - val_loss: 2.5320 - val_accuracy: 0.4503 - lr: 0.0010 - 512s/epoch - 3s/step
# Epoch 3/30
# 197/197 - 507s - loss: 1.2070 - accuracy: 0.5802 - val_loss: 1.0149 - val_accuracy: 0.6313 - lr: 0.0010 - 507s/epoch - 3s/step
# Epoch 4/30
# 197/197 - 537s - loss: 1.0233 - accuracy: 0.6200 - val_loss: 0.8449 - val_accuracy: 0.6997 - lr: 0.0010 - 537s/epoch - 3s/step
# Epoch 5/30
# 197/197 - 536s - loss: 0.9557 - accuracy: 0.6444 - val_loss: 1.7023 - val_accuracy: 0.5077 - lr: 0.0010 - 536s/epoch - 3s/step
# Epoch 6/30
# 197/197 - 509s - loss: 0.9060 - accuracy: 0.6723 - val_loss: 1.4503 - val_accuracy: 0.5530 - lr: 0.0010 - 509s/epoch - 3s/step
# Epoch 7/30
# 197/197 - 506s - loss: 0.8614 - accuracy: 0.6870 - val_loss: 1.4092 - val_accuracy: 0.4987 - lr: 0.0010 - 506s/epoch - 3s/step
# Epoch 8/30
# 197/197 - 507s - loss: 0.8516 - accuracy: 0.6905 - val_loss: 0.7067 - val_accuracy: 0.7520 - lr: 0.0010 - 507s/epoch - 3s/step
# Epoch 9/30
# 197/197 - 520s - loss: 0.8033 - accuracy: 0.7040 - val_loss: 4.1085 - val_accuracy: 0.4457 - lr: 0.0010 - 520s/epoch - 3s/step
# Epoch 10/30
# 197/197 - 511s - loss: 0.7729 - accuracy: 0.7188 - val_loss: 0.6642 - val_accuracy: 0.7587 - lr: 0.0010 - 511s/epoch - 3s/step
# Epoch 11/30
# 197/197 - 521s - loss: 0.7784 - accuracy: 0.7233 - val_loss: 0.6972 - val_accuracy: 0.7567 - lr: 0.0010 - 521s/epoch - 3s/step
# Epoch 12/30
# 197/197 - 503s - loss: 0.7161 - accuracy: 0.7429 - val_loss: 1.1363 - val_accuracy: 0.6890 - lr: 0.0010 - 503s/epoch - 3s/step
# Epoch 13/30
# 197/197 - 511s - loss: 0.7188 - accuracy: 0.7446 - val_loss: 1.0903 - val_accuracy: 0.6837 - lr: 0.0010 - 511s/epoch - 3s/step
# Epoch 14/30
# 197/197 - 499s - loss: 0.6797 - accuracy: 0.7542 - val_loss: 0.8414 - val_accuracy: 0.6933 - lr: 0.0010 - 499s/epoch - 3s/step
# Epoch 15/30
# 197/197 - 512s - loss: 0.6883 - accuracy: 0.7545 - val_loss: 0.7647 - val_accuracy: 0.7013 - lr: 0.0010 - 512s/epoch - 3s/step
# Epoch 16/30
# 197/197 - 510s - loss: 0.5927 - accuracy: 0.7891 - val_loss: 0.5374 - val_accuracy: 0.8127 - lr: 3.1623e-04 - 510s/epoch - 3s/step
# Epoch 17/30
# 197/197 - 512s - loss: 0.5586 - accuracy: 0.8001 - val_loss: 0.5284 - val_accuracy: 0.8110 - lr: 3.1623e-04 - 512s/epoch - 3s/step
# Epoch 18/30
# 197/197 - 495s - loss: 0.5462 - accuracy: 0.8017 - val_loss: 0.7520 - val_accuracy: 0.7453 - lr: 3.1623e-04 - 495s/epoch - 3s/step
# Epoch 19/30
# 197/197 - 500s - loss: 0.5196 - accuracy: 0.8111 - val_loss: 0.4745 - val_accuracy: 0.8447 - lr: 3.1623e-04 - 500s/epoch - 3s/step
# Epoch 20/30
# 197/197 - 491s - loss: 0.5210 - accuracy: 0.8197 - val_loss: 0.6071 - val_accuracy: 0.7947 - lr: 3.1623e-04 - 491s/epoch - 2s/step
# Epoch 21/30
# 197/197 - 511s - loss: 0.5079 - accuracy: 0.8220 - val_loss: 0.5574 - val_accuracy: 0.8137 - lr: 3.1623e-04 - 511s/epoch - 3s/step
# Epoch 22/30
# 197/197 - 536s - loss: 0.5160 - accuracy: 0.8177 - val_loss: 0.4673 - val_accuracy: 0.8343 - lr: 3.1623e-04 - 536s/epoch - 3s/step
# Epoch 23/30
# 197/197 - 517s - loss: 0.4866 - accuracy: 0.8327 - val_loss: 0.6906 - val_accuracy: 0.7833 - lr: 3.1623e-04 - 517s/epoch - 3s/step
# Epoch 24/30
# 197/197 - 498s - loss: 0.4946 - accuracy: 0.8216 - val_loss: 0.7079 - val_accuracy: 0.7653 - lr: 3.1623e-04 - 498s/epoch - 3s/step
# Epoch 25/30
# 197/197 - 508s - loss: 0.5031 - accuracy: 0.8233 - val_loss: 0.5112 - val_accuracy: 0.8287 - lr: 3.1623e-04 - 508s/epoch - 3s/step
# Epoch 26/30
# 197/197 - 516s - loss: 0.4681 - accuracy: 0.8380 - val_loss: 0.4681 - val_accuracy: 0.8413 - lr: 3.1623e-04 - 516s/epoch - 3s/step
# Epoch 27/30
# 197/197 - 511s - loss: 0.4628 - accuracy: 0.8377 - val_loss: 0.5570 - val_accuracy: 0.8280 - lr: 3.1623e-04 - 511s/epoch - 3s/step
# Epoch 28/30
# 197/197 - 515s - loss: 0.4392 - accuracy: 0.8469 - val_loss: 0.4523 - val_accuracy: 0.8490 - lr: 1.0000e-04 - 515s/epoch - 3s/step
# Epoch 29/30
# 197/197 - 518s - loss: 0.4235 - accuracy: 0.8525 - val_loss: 0.4734 - val_accuracy: 0.8417 - lr: 1.0000e-04 - 518s/epoch - 3s/step
# Epoch 30/30
# 197/197 - 518s - loss: 0.4114 - accuracy: 0.8596 - val_loss: 0.4645 - val_accuracy: 0.8470 - lr: 1.0000e-04 - 518s/epoch - 3s/step

# %% [markdown]
# Plotting the Model Metrics

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Testing the Model on Test Set

# %%
test_dataset = "C:/Users/pater/OneDrive/Documents/Code Practice/Deep Learning with Python/imgClassCNN/seg_test/seg_test"
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 6 classes.

# %%
predictions = cnn_model.predict(test_generator)
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()
# Out:
# 94/94 [==============================] - 52s 493ms/step

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 94/94 [==============================] - 56s 540ms/step - loss: 0.4645 - accuracy: 0.8470

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.464474081993103
# Test Accuracy: 0.847000002861023

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(6, 6)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.73      0.91      0.81       437
#       forest       0.95      0.97      0.96       474
#      glacier       0.86      0.76      0.81       553
#     mountain       0.83      0.77      0.80       525
#          sea       0.84      0.86      0.85       510
#       street       0.89      0.82      0.86       501
#
#     accuracy                           0.85      3000
#    macro avg       0.85      0.85      0.85      3000
# weighted avg       0.85      0.85      0.85      3000
